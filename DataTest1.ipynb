# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel("C:/Users/Admin/Downloads/Assignments/DATest_1.xlsx" , sheet_name = 1)
df
# Out:
#                                    User Id  Keyword  Vibe  \
# 0     0030b069-d45e-11ee-8482-128e718ba88f  Drivers     1
# 1     00831062-d45b-11ee-8482-128e718ba88f  Drivers     1
# 2     00ac49e8-d45a-11ee-8482-128e718ba88f  Drivers     3
# 3     00fd1031-d466-11ee-8482-128e718ba88f  Drivers     3
# 4     011c0f25-d464-11ee-8482-128e718ba88f  Drivers     1
# ...                                    ...      ...   ...
# 5248  fc3b09c3-d465-11ee-8482-128e718ba88f  Drivers     1
# 5249  fc3b09c3-d465-11ee-8482-128e718ba88f  Drivers     1
# 5250  fd339b8a-d469-11ee-8482-128e718ba88f  Drivers     1
# 5251  fd339b8a-d469-11ee-8482-128e718ba88f  Drivers     3
# 5252  fd339b8a-d469-11ee-8482-128e718ba88f  Drivers     1
#
#                     Keyword Notes
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ...                           ...
# ...

# %%
df["Keyword Notes"].unique()
# Out:
# array([nan, 'Control', 'Spacious', 'Unmissable Presence', 'Assurance',
#        'Comfort', 'Convenience', 'Sci Fi', 'Safety', 'Tough',
#        'Low Cost of Ownership', 'Powerful/Spirited Performance',
#        'Sophisticated', 'Customer Service', 'Dealership Sales Experience',
#        'Status', 'Aspirational', 'Good Value for Money',
#        'External Factors'], dtype=object)

# %%
df["Keyword Notes"].nunique()
# Out:
# 18

# %%
df["Keyword Notes"].value_counts()
# Out:
# Keyword Notes
# Low Cost of Ownership            536
# Convenience                      453
# Unmissable Presence              443
# Spacious                         428
# Control                          340
# Sci Fi                           296
# Powerful/Spirited Performance    292
# Comfort                          281
# Tough                            269
# Safety                           240
# Good Value for Money             220
# Assurance                        167
# Dealership Sales Experience      161
# Sophisticated                     69
# External Factors                  29
# Aspirational                      27
# Status                            23
# Customer Service                  10
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# User Id            0
# Keyword            0
# Vibe               0
# Keyword Notes    969
# dtype: int64

# %%
df.fillna(0 , inplace = True)

# %%
df.head()
# Out:
#                                 User Id  Keyword  Vibe Keyword Notes
# 0  0030b069-d45e-11ee-8482-128e718ba88f  Drivers     1             0
# 1  00831062-d45b-11ee-8482-128e718ba88f  Drivers     1             0
# 2  00ac49e8-d45a-11ee-8482-128e718ba88f  Drivers     3             0
# 3  00fd1031-d466-11ee-8482-128e718ba88f  Drivers     3             0
# 4  011c0f25-d464-11ee-8482-128e718ba88f  Drivers     1             0

# %%
df.groupby(["Keyword Notes" , "Vibe"])["Vibe"].count()
# Out:
# Keyword Notes                  Vibe
# 0                              1       465
#                                2         4
#                                3       500
# Aspirational                   1        26
#                                2         1
# Assurance                      1       147
#                                2        18
#                                3         2
# Comfort                        1       222
#                                2        50
#                                3         9
# Control                        1       308
#                                2        19
#                                3        13
# Convenience                    1       386
#                                2        36
#                                3        31
# Customer Service               1         5
#                                2         5
# Dealership Sales Experience    1       126
#                                2        26
# ...

# %%
df.head()
# Out:
#                                 User Id  Keyword  Vibe Keyword Notes
# 0  0030b069-d45e-11ee-8482-128e718ba88f  Drivers     1             0
# 1  00831062-d45b-11ee-8482-128e718ba88f  Drivers     1             0
# 2  00ac49e8-d45a-11ee-8482-128e718ba88f  Drivers     3             0
# 3  00fd1031-d466-11ee-8482-128e718ba88f  Drivers     3             0
# 4  011c0f25-d464-11ee-8482-128e718ba88f  Drivers     1             0

# %%
df.isna().sum()
# Out:
# User Id          0
# Keyword          0
# Vibe             0
# Keyword Notes    0
# dtype: int64

# %%
pivot_df = df.groupby(["Keyword Notes", "Vibe"])["Vibe"].size().unstack(fill_value = 0)
pivot_df
# Out:
# Vibe                             1   2    3
# Keyword Notes
# 0                              465   4  500
# Aspirational                    26   1    0
# Assurance                      147  18    2
# Comfort                        222  50    9
# Control                        308  19   13
# Convenience                    386  36   31
# Customer Service                 5   5    0
# Dealership Sales Experience    126  26    9
# External Factors                 2  27    0
# Good Value for Money           181  39    0
# Low Cost of Ownership          442  71   23
# Powerful/Spirited Performance  268  19    5
# Safety                         182  34   24
# Sci Fi                         173  87   36
# Sophisticated                   38  30    1
# Spacious                       308  82   38
# Status                          12  11    0
# Tough                          246  20    3
# Unmissable Presence            355  60   28

# %%
pivot_df.insert(loc = 3 , column = "Grand Total" , value = pivot_df.sum(axis=1))
pivot_df
# Out:
#                                  1   2    3  Grand Total
# Keyword Notes
# 0                              465   4  500          969
# Aspirational                    26   1    0           27
# Assurance                      147  18    2          167
# Comfort                        222  50    9          281
# Control                        308  19   13          340
# Convenience                    386  36   31          453
# Customer Service                 5   5    0           10
# Dealership Sales Experience    126  26    9          161
# External Factors                 2  27    0           29
# Good Value for Money           181  39    0          220
# Low Cost of Ownership          442  71   23          536
# Powerful/Spirited Performance  268  19    5          292
# Safety                         182  34   24          240
# Sci Fi                         173  87   36          296
# Sophisticated                   38  30    1           69
# ...

# %%
pivot_df
# Out:
#                                  1   2    3  Grand Total
# Keyword Notes
# 0                              465   4  500          969
# Aspirational                    26   1    0           27
# Assurance                      147  18    2          167
# Comfort                        222  50    9          281
# Control                        308  19   13          340
# Convenience                    386  36   31          453
# Customer Service                 5   5    0           10
# Dealership Sales Experience    126  26    9          161
# External Factors                 2  27    0           29
# Good Value for Money           181  39    0          220
# Low Cost of Ownership          442  71   23          536
# Powerful/Spirited Performance  268  19    5          292
# Safety                         182  34   24          240
# Sci Fi                         173  87   36          296
# Sophisticated                   38  30    1           69
# ...

# %%
pivot_df.columns.name = None

# %%
pivot_df.head()
# Out:
#                  1   2    3
# Keyword Notes
# 0              465   4  500
# Aspirational    26   1    0
# Assurance      147  18    2
# Comfort        222  50    9
# Control        308  19   13

# %%
df2 = pivot_df[(pivot_df[1] > 0) & (pivot_df[2] > 0) & (pivot_df[3] > 0)]

# %%
df2.head()
# Out:
#                  1   2    3  Grand Total
# Keyword Notes
# 0              465   4  500          969
# Assurance      147  18    2          167
# Comfort        222  50    9          281
# Control        308  19   13          340
# Convenience    386  36   31          453

# %%
df2.shape
# Out:
# (14, 4)

# %%
df2.size
# Out:
# 56

# %%
df2.ndim
# Out:
# 2

# %%
df2.head()
# Out:
#                  1   2    3  Grand Total
# Keyword Notes
# 0              465   4  500          969
# Assurance      147  18    2          167
# Comfort        222  50    9          281
# Control        308  19   13          340
# Convenience    386  36   31          453

# %%
df2.insert(loc = 1 , column = "(blank)" , value = "")
df2.head()
# Out:
#                  1 (blank)   2    3  Grand Total
# Keyword Notes
# 0              465           4  500          969
# Assurance      147          18    2          167
# Comfort        222          50    9          281
# Control        308          19   13          340
# Convenience    386          36   31          453

# %%
divide_value = df2["Grand Total"].iloc[0]
# Remove rows where Keyword Notes is blank or 0


x = np.round(df2[1].div(divide_value).mul(100).fillna(0))
y = np.round(df2[2].div(divide_value).mul(100).fillna(0))
z = np.round(df2[3].div(divide_value).mul(100).fillna(0))

df2["Positive"] = x.apply(lambda val: f"{int(val)}%")
df2["Mixed"] = z.apply(lambda val: f"{int(val)}%")
df2["Negative"] = y.apply(lambda val: f"{int(val)}%")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9612\1762658868.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Positive"] = x.apply(lambda val: f"{int(val)}%")
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9612\1762658868.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Mixed"] = z.apply(lambda val: f"{int(val)}%")
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9612\1762658868.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df2.head()
# Out:
#                  1 (blank)   2    3  Grand Total Positive Mixed Negative
# Keyword Notes
# 0              465           4  500          969      48%   52%       0%
# Assurance      147          18    2          167      15%    0%       2%
# Comfort        222          50    9          281      23%    1%       5%
# Control        308          19   13          340      32%    1%       2%
# Convenience    386          36   31          453      40%    3%       4%

# %%
df2.insert(loc=5, column="Neutral", value="0%")

# %%
df2.head()
# Out:
#                  1 (blank)   2    3  Grand Total Neutral Positive Mixed  \
# Keyword Notes
# 0              465           4  500          969      0%      48%   52%
# Assurance      147          18    2          167      0%      15%    0%
# Comfort        222          50    9          281      0%      23%    1%
# Control        308          19   13          340      0%      32%    1%
# Convenience    386          36   31          453      0%      40%    3%
#
#               Negative
# Keyword Notes
# 0                   0%
# Assurance           2%
# Comfort             5%
# Control             2%
# Convenience         4%

# %%
df2["Total"] = (
    df2[["Positive", "Negative", "Mixed"]]
    .apply(lambda row: sum(int(val.replace("%", "")) for val in row), axis=1)
    .astype(str) + "%"
)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9612\4288907961.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Total"] = (

# %%
df2.rename({"Total" : "Grand Total"} , inplace = True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9612\1862297615.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.rename({"Total" : "Grand Total"} , inplace = True)

# %%
df2
# Out:
#                                  1 (blank)   2    3  Grand Total Positive  \
# Keyword Notes
# 0                              465           4  500          969      48%
# Assurance                      147          18    2          167      15%
# Comfort                        222          50    9          281      23%
# Control                        308          19   13          340      32%
# Convenience                    386          36   31          453      40%
# Dealership Sales Experience    126          26    9          161      13%
# Low Cost of Ownership          442          71   23          536      46%
# Powerful/Spirited Performance  268          19    5          292      28%
# Safety                         182          34   24          240      19%
# Sci Fi                         173          87   36          296      18%
# Sophisticated                   38          30    1           69       4%
# ...
